# %%
pip install git+https://github.com/lujiec2020/TEEM2.git
# Out:
# Collecting git+https://github.com/lujiec2020/TEEM2.git
#   Cloning https://github.com/lujiec2020/TEEM2.git to c:\users\supak\appdata\local\temp\pip-req-build-3o_835j7
#   Resolved https://github.com/lujiec2020/TEEM2.git to commit 28443cba6ac0dbcfe6a3c3889d00496c3f8efdbe
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/lujiec2020/TEEM2.git 'C:\Users\supak\AppData\Local\Temp\pip-req-build-3o_835j7'
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [2 lines of output]
#       running egg_info
#       error: error in 'egg_base' option: 'src' does not exist or is not a directory
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 25.3 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Failed to build 'git+https://github.com/lujiec2020/TEEM2.git' when getting requirements to build wheel

# %%
pip install datascience
# Out:
# Requirement already satisfied: datascience in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (0.18.1)
# Requirement already satisfied: folium>=0.9.1 in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from datascience) (0.20.0)
# Requirement already satisfied: setuptools in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from datascience) (82.0.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from datascience) (3.10.8)
# Requirement already satisfied: pandas in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from datascience) (2.3.3)
# Requirement already satisfied: scipy in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from datascience) (1.17.1)
# Requirement already satisfied: numpy in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from datascience) (2.4.3)
# Requirement already satisfied: ipython in c:\users\supak\appdata\roaming\python\python313\site-packages (from datascience) (9.12.0)
# Requirement already satisfied: plotly in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from datascience) (6.7.0)
# Requirement already satisfied: branca in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from datascience) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from folium>=0.9.1->datascience) (3.1.6)
# Requirement already satisfied: requests in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from folium>=0.9.1->datascience) (2.32.5)
# Requirement already satisfied: xyzservices in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from folium>=0.9.1->datascience) (2026.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from jinja2>=2.9->folium>=0.9.1->datascience) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->datascience) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->datascience) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->datascience) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->datascience) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->datascience) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->datascience) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->datascience) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->datascience) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->datascience) (1.17.0)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from ipython->datascience) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in c:\users\supak\appdata\roaming\python\python313\site-packages (from ipython->datascience) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\supak\appdata\roaming\python\python313\site-packages (from ipython->datascience) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in c:\users\supak\appdata\roaming\python\python313\site-packages (from ipython->datascience) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in c:\users\supak\appdata\roaming\python\python313\site-packages (from ipython->datascience) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\supak\appdata\roaming\python\python313\site-packages (from ipython->datascience) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from ipython->datascience) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\supak\appdata\roaming\python\python313\site-packages (from ipython->datascience) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\supak\appdata\roaming\python\python313\site-packages (from ipython->datascience) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\supak\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->datascience) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\supak\appdata\roaming\python\python313\site-packages (from jedi>=0.18.2->ipython->datascience) (0.8.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\supak\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython->datascience) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\supak\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython->datascience) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\supak\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython->datascience) (0.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from pandas->datascience) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from pandas->datascience) (2025.3)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from plotly->datascience) (2.18.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from requests->folium>=0.9.1->datascience) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from requests->folium>=0.9.1->datascience) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from requests->folium>=0.9.1->datascience) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (from requests->folium>=0.9.1->datascience) (2026.2.25)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pytz
# Out:
# Requirement already satisfied: pytz in c:\users\supak\appdata\local\programs\python\python313\lib\site-packages (2026.1.post1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from social_media_functions.parse_metadata import social_media_events

t = social_media_events(
    instagram_folder="data/instagram_data",
    tiktok_json="data/tiktok_data/user_data_tiktok.json"
)

t.show(5)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from social_media_functions.parse_metadata import social_media_events
#       2
#       3 t = social_media_events(
#       4     instagram_folder="data/instagram_data",
#
# File c:\Users\supak\OneDrive\Desktop\Github\TEEM2\social_media_functions\parse_metadata\__init__.py:7
#       1 """
#       2 social_media_functions
#       3
#       4 Beginner-friendly tools for parsing Instagram and TikTok data exports.
#       5 """
# ----> 7 from .parse_metadata import (
#       8     parse_metadata,
#       9     tiktok_events,
#      10     social_media_events,
#      11     events_by_hour,
#      12     events_by_weekday,
#      13     events_by_date,
#      14     StudentInputError,
#      15 )
#      17 __all__ = [
#      18     "StudentInputError",
#      19     "parse_metadata",
#    (...)     24     "events_by_date",
#      25 ]
#
# ModuleNotFoundError: No module named 'social_media_functions.parse_metadata.parse_metadata'
